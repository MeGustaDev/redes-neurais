# %% [markdown]
# 1) Refazer os exemplos do último trabalho usando outras funções de ativação (tanh e ReLU) ... e pensar a respeito: nesse problema, qual foi a melhor? ... como se pode saber qual é mais eficiente? quantidade de épocas necessárias para aprender? tempo de execução?...

# %% [markdown]
# Base de dados utilizada (Flor do Gênero Iris)
# https://archive.ics.uci.edu/dataset/53/iris

# %% [markdown]
# # Análise entre as funções de ativação tanh e ReLU

# %% [markdown]
# Ambos algoritmos com
# eta=0.00002;
# epocas=1000;
# utilizando o algoritmo de descida do gradiente

# %% [markdown]
# # Table

# %% [markdown]
# | Função de Ativação | CPU Time | Wall Time | Accuracy Score |
# |:------------------:|:--------:|-----------|----------------|
# | Tanh               | 46.9     | 38.6      | 1.00           |
# | ReLU               | 31.2     | 26.1      | 0.95           |

# %% [markdown]
# Tanh
# ![image.png](attachment:image.png)
# ReLU
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Tanh
# ![image.png](attachment:image.png)
# ReLU
# ![image-2.png](attachment:image-2.png)
